# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# call DAILY dataset
# list_state = ['48', '36', '06']
# df = pd.DataFrame()
# for state in list_state:
#     try:
#         url = 'https://aqs.epa.gov/data/api/dailyData/byState?'
#         params = {'email': 'cnnewkirk@gmail.com',
#                  'key': 'baywolf26',
#                  'param': '88101',
#                  'bdate':'20200101',
#                  'edate':'20201201',
#                  'state': state}

#         response = requests.get(url, params=params).json()
#         data=response['Data']
#         int_df = pd.DataFrame(data)
#         df = df.append(int_df)
#     except:
#         pass
# df

# %%
# unique_sites = df.site_number.unique()
# unique_sites.sort()
# unique_sites
# for col in df.columns:
#     print(col)

# %%
# df.to_csv('/Users/christinenewkirk/Documents/coursework/usc-la-virt-data-pt-09-2021-u-c/air_quality_analysis/CNanalysis')

# %%
# call annual PM25 2012 dataset (with EPA calculated average values)
list_state = ['48', '36', '06']
df_annual = pd.DataFrame()
for state in list_state:
    try:
        url_2 = 'https://aqs.epa.gov/data/api/annualData/byState?'
        params = {'email': email,
                 'key': epa_key,
                 'param': '88101',
                 'bdate':'20200101',
                 'edate':'20201201',
                 'state': state}

        response = requests.get(url_2, params=params).json()
        data=response['Data']
        int_df = pd.DataFrame(data)
        df_annual = df_annual.append(int_df)
    except:
        pass
df_annual
# Out:
#      state_code county_code site_number parameter_code  poc   latitude  \
# 0            48         375        0320          88101    2  35.201592
# 1            48         375        0320          88101    2  35.201592
# 2            48         375        0320          88101    2  35.201592
# 3            48         375        0320          88101    2  35.201592
# 4            48         375        0320          88101    2  35.201592
# ...         ...         ...         ...            ...  ...        ...
# 1492         06         001        0013          88101    3  37.864767
# 1493         06         001        0013          88101    3  37.864767
# 1494         06         001        0013          88101    3  37.864767
# 1495         06         001        0013          88101    3  37.864767
# 1496         06         001        0013          88101    3  37.864767
#
#        longitude  datum                 parameter sample_duration_code  ...  \
# 0    -101.909275  WGS84  PM2.5 - Local Conditions                    X  ...
# 1    -101.909275  WGS84  PM2.5 - Local Conditions                    X  ...
# 2    -101.909275  WGS84  PM2.5 - Local Conditions                    X  ...
# 3    -101.909275  WGS84  PM2.5 - Local Conditions                    X  ...
# 4    -101.909275  WGS84  PM2.5 - Local Conditions                    X  ...
# ...          ...    ...                       ...                  ...  ...
# 1492 -122.302741  NAD83  PM2.5 - Local Conditions                    X  ...
# 1493 -122.302741  NAD83  PM2.5 - Local Conditions                    X  ...
# 1494 -122.302741  NAD83  PM2.5 - Local Conditions                    X  ...
# 1495 -122.302741  NAD83  PM2.5 - Local Conditions                    X  ...
# 1496 -122.302741  NAD83  PM2.5 - Local Conditions                    X  ...
#
#      fiftieth_percentile tenth_percentile        local_site_name  \
# 0                    4.7              2.0           Amarillo A&M
# 1                    4.7              2.0           Amarillo A&M
# 2                    4.7              2.0           Amarillo A&M
# 3                    4.7              2.0           Amarillo A&M
# 4                    4.7              2.0           Amarillo A&M
# ...                  ...              ...                    ...
# 1492                 8.7              4.7  Berkeley Aquatic Park
# 1493                 8.7              4.7  Berkeley Aquatic Park
# 1494                 8.7              4.7  Berkeley Aquatic Park
# 1495                 8.7              4.7  Berkeley Aquatic Park
# 1496                 8.7              4.7  Berkeley Aquatic Park
#
#                  site_address       state   county      city  cbsa_code  \
# 0     6500 Amarillo Blvd West       Texas   Potter  Amarillo      11100
# 1     6500 Amarillo Blvd West       Texas   Potter  Amarillo      11100
# 2     6500 Amarillo Blvd West       Texas   Potter  Amarillo      11100
# 3     6500 Amarillo Blvd West       Texas   Potter  Amarillo      11100
# 4     6500 Amarillo Blvd West       Texas   Potter  Amarillo      11100
# ...                       ...         ...      ...       ...        ...
# 1492             1 Bolivar Dr  California  Alameda      None      41860
# 1493             1 Bolivar Dr  California  Alameda      None      41860
# 1494             1 Bolivar Dr  California  Alameda      None      41860
# 1495             1 Bolivar Dr  California  Alameda      None      41860
# 1496             1 Bolivar Dr  California  Alameda      None      41860
#
#                                    cbsa date_of_last_change
# 0                          Amarillo, TX          2021-10-31
# 1                          Amarillo, TX          2021-10-31
# 2                          Amarillo, TX          2021-10-31
# 3                          Amarillo, TX          2021-10-31
# 4                          Amarillo, TX          2021-10-31
# ...                                 ...                 ...
# 1492  San Francisco-Oakland-Hayward, CA          2021-10-31
# 1493  San Francisco-Oakland-Hayward, CA          2021-10-31
# 1494  San Francisco-Oakland-Hayward, CA          2021-10-31
# 1495  San Francisco-Oakland-Hayward, CA          2021-10-31
# 1496  San Francisco-Oakland-Hayward, CA          2021-10-31
#
# [2038 rows x 56 columns]

# %%
# df_annual.to_csv('/Users/christinenewkirk/Documents/coursework/usc-la-virt-data-pt-09-2021-u-c/air_quality_analysis/CNanalysis_annual')

# %%
# df_annual.dtypes

# %%
# Generate a list of unique sites

# see below

# %%
# remove all rows from the annual dataframe where "pollutant standard" does NOT EQUAL "PM25 Annual 2012"
# this new dataframe will be used for analysis

PM25_annual_2012 = df_annual.loc[df_annual['pollutant_standard'] == 'PM25 Annual 2012']
PM25_annual_2012['pollutant_standard']
# Out:
# 2       PM25 Annual 2012
# 9       PM25 Annual 2012
# 16      PM25 Annual 2012
# 23      PM25 Annual 2012
# 29      PM25 Annual 2012
#               ...
# 1466    PM25 Annual 2012
# 1473    PM25 Annual 2012
# 1480    PM25 Annual 2012
# 1487    PM25 Annual 2012
# 1494    PM25 Annual 2012
# Name: pollutant_standard, Length: 311, dtype: object

# %%
# How many entries do we have where pollutant standard = PM25 Annual 2012?
# total_rows = PM25_annual_2012.count()
# print(total_rows + 1)

# %%
# This dataframe has 311 entries -- how many unique site numbers are there?
unique_sites_annual = PM25_annual_2012.site_number.unique()
unique_sites_annual.sort()
print(len('unique_sites_annual'))
# Out:
# 19

# %%
# print the dataset

PM25_annual_2012.to_csv("../air_quality_analysis/PM25_2012_only.csv")

# %%
# seems the most unique identifier is lat + lng, and there are still multiple entries for each of these combos.
# it looks like the same site has multiple entries under "event type." Here is the description of this variable https://aqs.epa.gov/aqsweb/documents/about_aqs_data.html (section 4.2.2)
# select only records where "event type" is "events excluded" or "no event"
array=['Events Excluded', 'No Events']
PM25_annual_2012_final = PM25_annual_2012.loc[PM25_annual_2012['event_type'].isin(array)]
print(PM25_annual_2012_final)


# select only records where "sample duration"
# Out:
#      state_code county_code site_number parameter_code  poc   latitude  \
# 2            48         375        0320          88101    2  35.201592
# 9            48         453        0014          88101    1  30.354944
# 16           48         453        0021          88101    3  30.263204
# 23           48         453        0021          88101    2  30.263204
# 29           48         453        1068          88101    2  30.353860
# ...         ...         ...         ...            ...  ...        ...
# 1466         06         019        2009          88101    3  36.634225
# 1473         06         047        0003          88101    3  37.281853
# 1480         06         067        5003          88101    3  38.494475
# 1487         06         087        1005          88101    3  37.063150
# 1494         06         001        0013          88101    3  37.864767
#
#        longitude  datum                 parameter sample_duration_code  ...  \
# 2    -101.909275  WGS84  PM2.5 - Local Conditions                    X  ...
# 9     -97.761803  NAD83  PM2.5 - Local Conditions                    X  ...
# 16    -97.712891  NAD83  PM2.5 - Local Conditions                    X  ...
# 23    -97.712891  NAD83  PM2.5 - Local Conditions                    7  ...
# 29    -97.691660  NAD83  PM2.5 - Local Conditions                    X  ...
# ...          ...    ...                       ...                  ...  ...
# 1466 -120.382331  WGS84  PM2.5 - Local Conditions                    X  ...
# 1473 -120.433671  NAD83  PM2.5 - Local Conditions                    X  ...
# 1480 -121.211131  WGS84  PM2.5 - Local Conditions                    X  ...
# 1487 -122.083092  NAD83  PM2.5 - Local Conditions                    X  ...
# 1494 -122.302741  NAD83  PM2.5 - Local Conditions                    X  ...
#
#      fiftieth_percentile tenth_percentile                   local_site_name  \
# 2                    4.7              2.0                      Amarillo A&M
# 9                    5.8              2.7          Austin North Hills Drive
# 16                   8.4              4.6             Austin Webberville Rd
# 23                   7.4              4.7             Austin Webberville Rd
# 29                   8.3              4.5        Austin North Interstate 35
# ...                  ...              ...                               ...
# 1466                 5.8              1.1                      Tranquillity
# 1473                 9.2              4.7                     Merced-Coffee
# 1480                 7.0              3.2                       Sloughhouse
# 1487                 4.0              0.5  San Lorenzo Valley Middle School
# 1494                 8.7              4.7             Berkeley Aquatic Park
#
#                                        site_address       state      county  \
# 2                           6500 Amarillo Blvd West       Texas      Potter
# 9                            3824 North Hills Drive       Texas      Travis
# 16                             2600B Webberville Rd       Texas      Travis
# 23                             2600B Webberville Rd       Texas      Travis
# 29                             8912 N IH 35 SVRD SB       Texas      Travis
# ...                                             ...         ...         ...
# 1466  32650 West Adams Avenue Tranquillity CA 93668  California      Fresno
# 1473         385 S. COFFEE AVENUE, MERCED, CA 95340  California      Merced
# 1480             7250 SLOUGHHOUSE ROAD, SLOUGHHOUSE  California  Sacramento
# 1487             7179 Hacienda Way, Felton CA 95018  California  Santa Cruz
# 1494                                   1 Bolivar Dr  California     Alameda
#
#           city  cbsa_code                                     cbsa  \
# 2     Amarillo      11100                             Amarillo, TX
# 9       Austin      12420                    Austin-Round Rock, TX
# 16      Austin      12420                    Austin-Round Rock, TX
# 23      Austin      12420                    Austin-Round Rock, TX
# 29      Austin      12420                    Austin-Round Rock, TX
# ...        ...        ...                                      ...
# 1466      None      23420                               Fresno, CA
# 1473      None      32900                               Merced, CA
# 1480      None      40900  Sacramento--Roseville--Arden-Arcade, CA
# 1487      None      42100               Santa Cruz-Watsonville, CA
# 1494      None      41860        San Francisco-Oakland-Hayward, CA
#
#      date_of_last_change
# 2             2021-10-31
# 9             2021-10-31
# 16            2021-10-31
# 23            2021-10-31
# 29            2021-10-31
# ...                  ...
# 1466          2021-10-31
# 1473          2021-10-31
# 1480          2021-10-31
# 1487          2021-10-31
# 1494          2021-10-31
#
# [245 rows x 56 columns]

# %%
# print csv
PM25_annual_2012_final.to_csv("../air_quality_analysis/PM25_2012_final.csv")

# %%
# reverse geocode each latlng pair to find the corresponding zip codes

# base_url = "https://maps.googleapis.com/maps/api/geocode/json?latlng=['latitude'],['longitude']&key=['gkey']"

# do I read the dataframe and turn latitude into a list, and turn longitude into a list? and then iterate through the
# latitudes and longitudes?



# iterate through each latitude and longitude in the list and return ZIP codes
latlng_df = pd.read_csv("../air_quality_analysis/PM25_2012_final.csv")
latlng_df.head()

latlng_pairs = list(zip(latlng_df['latitude'],latlng_df['longitude']))

print(latlng_pairs)


# for pair in latlng_pairs


# latlng_df['latitudes']=""
# latlng_df['longitudes']=""
# latlng_df['ZIP']=""



# generate a ZIP for each pair

# join the ZIP

# generate a % living in poverty for each pair

# join the % living in poverty
# Out:
# [(35.201592, -101.909275), (30.354944, -97.761803), (30.263203999999998, -97.712891), (30.263203999999998, -97.712891), (30.353859999999997, -97.69166), (29.770698, -95.03123199999999), (25.892518, -97.49383), (30.628333, -96.36277700000001), (27.804489, -97.43155300000001), (27.804489, -97.43155300000001), (27.811816999999998, -97.465703), (27.426981, -97.298692), (32.774262, -96.797686), (32.820060999999995, -96.860117), (32.820060999999995, -96.860117), (32.820060999999995, -96.860117), (29.670025, -95.128508), (29.670025, -95.128508), (33.219069, -97.19628399999999), (28.704607, -100.45115600000001), (26.288621999999997, -98.152066), (31.768286, -106.50124299999999), (31.765684999999998, -106.45522700000001), (31.765684999999998, -106.45522700000001), (32.80581, -97.35652900000001), (32.759153999999995, -97.342332), (32.664753000000005, -97.337917), (32.664753000000005, -97.337917), (29.254474, -94.861289), (29.901035999999998, -95.326137), (29.901035999999998, -95.326137), (29.767996999999998, -95.220582), (29.733726, -95.257593), (29.733726, -95.257593), (29.814529999999998, -95.38769), (27.599444000000002, -99.533333), (33.58553, -101.78698), (29.162996999999997, -98.589158), (32.482083, -97.026899), (26.22621, -98.291069), (31.870259000000004, -102.334745), (29.922