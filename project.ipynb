# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
list_state = ['48', '36', '06']
df = pd.DataFrame()
for state in list_state:
    try:
        url = 'https://aqs.epa.gov/data/api/dailyData/byState?'
        params = {'email': 'jwwstauf@gmail.com',
                 'key': 'boleram91',
                 'param': '88101',
                 'bdate':'20200101',
                 'edate':'20201201',
                 'state': state}

        response = requests.get(url, params=params).json()
        data=response['Data']
        int_df = pd.DataFrame(data)
        df = df.append(int_df)
    except:
        pass
df
# Out:
#        state_code county_code site_number parameter_code  poc   latitude  \
# 0              48         323        0004          88101    1  28.704607
# 1              48         323        0004          88101    1  28.704607
# 2              48         323        0004          88101    1  28.704607
# 3              48         323        0004          88101    1  28.704607
# 4              48         323        0004          88101    1  28.704607
# ...           ...         ...         ...            ...  ...        ...
# 244669         06         011        1002          88101    1  39.189190
# 244670         06         011        1002          88101    1  39.189190
# 244671         06         011        1002          88101    1  39.189190
# 244672         06         011        1002          88101    1  39.189190
# 244673         06         011        1002          88101    1  39.189190
#
#          longitude  datum                 parameter sample_duration_code  ...  \
# 0      -100.451156  WGS84  PM2.5 - Local Conditions                    1  ...
# 1      -100.451156  WGS84  PM2.5 - Local Conditions                    X  ...
# 2      -100.451156  WGS84  PM2.5 - Local Conditions                    X  ...
# 3      -100.451156  WGS84  PM2.5 - Local Conditions                    X  ...
# 4      -100.451156  WGS84  PM2.5 - Local Conditions                    X  ...
# ...            ...    ...                       ...                  ...  ...
# 244669 -121.998870  NAD83  PM2.5 - Local Conditions                    7  ...
# 244670 -121.998870  NAD83  PM2.5 - Local Conditions                    7  ...
# 244671 -121.998870  NAD83  PM2.5 - Local Conditions                    7  ...
# 244672 -121.998870  NAD83  PM2.5 - Local Conditions                    7  ...
# 244673 -121.998870  NAD83  PM2.5 - Local Conditions                    7  ...
#
#        method_code                                             method  \
# 0              209  Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM...
# 1              209  Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM...
# 2              209  Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM...
# 3              209  Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM...
# 4              209  Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM...
# ...            ...                                                ...
# 244669         143  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...
# 244670         143  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...
# 244671         143  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...
# 244672         143  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...
# 244673         143  R & P Model 2000 PM-2.5 Air Sampler w/VSCC - G...
#
#             local_site_name               site_address       state    county  \
# 0                Eagle Pass       265 Foster Maldonado       Texas  Maverick
# 1                Eagle Pass       265 Foster Maldonado       Texas  Maverick
# 2                Eagle Pass       265 Foster Maldonado       Texas  Maverick
# 3                Eagle Pass       265 Foster Maldonado       Texas  Maverick
# 4                Eagle Pass       265 Foster Maldonado       Texas  Maverick
# ...                     ...                        ...         ...       ...
# 244669  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California    Colusa
# 244670  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California    Colusa
# 244671  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California    Colusa
# 244672  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California    Colusa
# 244673  Colusa-Sunrise Blvd  100 SUNRISE BLVD., COLUSA  California    Colusa
#
#               city cbsa_code            cbsa  date_of_last_change
# 0       Eagle Pass     20580  Eagle Pass, TX           2021-10-31
# 1       Eagle Pass     20580  Eagle Pass, TX           2021-10-31
# 2       Eagle Pass     20580  Eagle Pass, TX           2021-10-31
# 3       Eagle Pass     20580  Eagle Pass, TX           2021-10-31
# 4       Eagle Pass     20580  Eagle Pass, TX           2021-10-31
# ...            ...       ...             ...                  ...
# 244669      Colusa      None            None           2021-10-31
# 244670      Colusa      None            None           2021-10-31
# 244671      Colusa      None            None           2021-10-31
# 244672      Colusa      None            None           2021-10-31
# 244673      Colusa      None            None           2021-10-31
#
# [356879 rows x 32 columns]
